# %%
import pandas as pd

# %%
it_pc = pd.read_csv('it_pc.csv')
f'There are {it_pc.shape[1]} columns'
# Out:
# 'There are 85 columns'

# %%
f'And {it_pc.shape[0]} rows'
# Out:
# 'And 1000 rows'

# %%
it_pc
# Out:
#      Part Number                          Part Description Vendor Name  \
# 0        3689016       MB16AC ZENSCREEN 15.6 USB C MONITOR        ASUS
# 1        3716572     XG27VQ 27IN CURVED FHD HDMI/DP MNT 3Y        ASUS
# 2        4350284      VG278QR 27IN TN FHD HDMI DP DVI-D 3Y        ASUS
# 3        4529707       MB16AMT 15.6IN IPS FHD MHDMI USB 3Y        ASUS
# 4        4529711       PG35VQ 35IN VA CURVED 4K HDMI DP 3Y        ASUS
# ..           ...                                       ...         ...
# 995      4947956  X360 1030G7 I5 16G 256G BV PEN W10P TILE          HP
# 996      4947957    X360 1030G7 I5 16G 256G BV 4G PEN W10P          HP
# 997      4947958    X360 1030G7 I5 16G 512G BV SVR 4G W10P          HP
# 998      4947959       X360 1030G7 I5 16G 512G BV PEN W10P          HP
# 999      4947960   X360 1030G7 I5 16G 512G UHD BV PEN W10P          HP
#
#      Customer Part Number Vendor Part Number   EANUPC Code Plant  \
# ...
